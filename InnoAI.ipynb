# %%
import numpy

m01 = numpy.matrix([6, -8, 3])
m02 = numpy.matrix([[1], [1], [4]])
m03 = m01 * m02
print(m03)

m11 = numpy.matrix([[-3, -7], [-10, 6], [0, -6], [-1, -3]])
m12 = numpy.matrix([[-8, 9], [4, -2]])
m13 = m11 * m12
print(m13)
# Out:
# [[10]]
# [[  -4  -13]
#  [ 104 -102]
#  [ -24   12]
#  [  -4   -3]]
